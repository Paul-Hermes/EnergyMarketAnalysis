# %% [markdown]
# # Conclusion
# TODO
# - We have been using actual weather data instead of forecast weather data, which would not be available at the point in time in which we would need to make the prediction.
#   - "reduces" the problem of energy prices to predicting weather if done reliably,
